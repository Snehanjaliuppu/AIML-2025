# %% [markdown]
# <a href="https://colab.research.google.com/github/Snehanjaliuppu/AIML-2025/blob/main/pns%20labexam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.array([10, 15, 20, 25, 30, 35])
y= np.array([68, 60, 55, 48, 38, 32])
plt.scatter(x, y, color='blue')
plt.title('Scatter Diagram of Pens Sold vs. \nPrice')
plt.xlabel('Price (Rs)')
plt.ylabel('Number of Pens Sold')
plt.grid(True)
plt.show()
correlation = np.corrcoef(x, y)[0, 1]
print(f"Pearson Correlation Coefficient: {correlation:.3f}")
# Out:
# Pearson Correlation Coefficient: -0.997
# Pearson Correlation Coefficient: -0.997
# Pearson Correlation Coefficient: -0.997
